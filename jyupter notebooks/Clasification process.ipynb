# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from numpy.linalg import eig
import pandas as pd
from minisom import MiniSom  
import math
import ipynb
from sklearn.metrics import classification_report
import cv2
from itertools import chain
# Import custom functions from seperate workbook
from ipynb.fs.full.helper_functions import *

# %matplotlib inline

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
def classify(som, x_test, x_train, y_train):
    
    # For each image we assign the label to the winning nuron
    winmap = som.labels_map(x_train, y_train)
    # Here we fiding the default class to assign something to the output when thhere is no winmap value for a given value
    default_class = np.sum(list(winmap.values())).most_common()[0][0]
    result = []
    for d in x_test:
        # Find the winning node for the given sample
        win_position = som.winner(d)
        # Check if that sample is in the list of posible results
        if win_position in winmap:
            # it is! great, now append the most common result for that sample for that node and its given image
            result.append(winmap[win_position].most_common()[0][0])
        else:
            result.append(default_class)
    return result

# %%
def create_train_som(x_train, n_features):
    
    # Create SOM dimensions
    som_nurons = int((math.sqrt(5*math.sqrt(n_features))))
#     print(som_nurons)
    x = som_nurons
    y = som_nurons
    
    #Create and train SOM
    som = MiniSom(x, y, n_features, sigma=0.3, learning_rate=0.5) # initialization of 6x6 SOM
    som.random_weights_init(x_train)
    print("Training...")
    som.train_random(x_train,100, verbose=False) # training with 100 iterations
    print("...ready!")
    return som

# %%
def flatten_and_reshape(data):
    res = np.reshape(data, (data.shape[0], data.shape[1]*data.shape[2]))
    return(res)

# %%
x_test_flat = flatten_and_reshape(x_test)
x_train_flat = flatten_and_reshape(x_train)

# %%
first_som = create_train_som(x_train_flat, 784)
# Out:
# Training...
# ...ready!

# %%
winmap = first_som.labels_map(x_train_flat, y_train)
# default_class = np.sum(list(winmap.values())).most_common()[0][0]
# result = []

# %%
default_class = np.sum(list(winmap.values())).most_common()[0][0]

# %%
default_class
# Out:
# 1

# %%
winmap
# Out:
# defaultdict(list,
#             {(4,
#               1): Counter({5: 663,
#                       3: 1551,
#                       8: 470,
#                       9: 38,
#                       2: 81,
#                       0: 9,
#                       6: 1,
#                       1: 2,
#                       7: 1}),
#              (8,
#               2): Counter({0: 2031,
#                       5: 80,
#                       2: 47,
#                       9: 11,
#                       3: 56,
#                       6: 63,
#                       8: 11,
#                       7: 1,
#                       4: 1}),
#              (1,
#               9): Counter({4: 1186,
#                       9: 847,
#                       8: 74,
#                       0: 16,
#                       2: 113,
#                       6: 66,
#                       5: 93,
#                       7: 86,
#                       3: 37}),
#              (4,
#               5): Counter({1: 1095,
#                       7: 17,
#                       2: 65,
#                       4: 14,
#                       8: 14,
#                       3: 1,
#                       6: 3,
#                       9: 1}),
#              (6,
#               10): Counter({9: 1366,
#                       4: 649,
#                       1: 1,
#                       8: 64,
#                       2: 4,
#                       7: 133,
#                       5: 234,
#                       3: 12}),
#              (0,
#               10): Counter({2: 455,
#                       8: 1205,
#                       3: 108,
#                       5: 21,
#                       6: 5,
#                       4: 7,
#                       9: 10,
#                       1: 5,
#                       7: 17,
#                       0: 3}),
#              (1,
#               8): Counter({1: 944,
#                       7: 32,
#                       8: 25,
#                       2: 2,
#                       4: 29,
#                       3: 25,
#                       5: 12,
#                       9: 12}),
#              (4,
#               0): Counter({4: 599,
#                       9: 555,
#                       7: 553,
#                       3: 13,
#                       8: 89,
#                       1: 4,
#                       2: 42,
#                       5: 26,
#                       0: 6,
#                       6: 2}),
#              (7,
#               2): Counter({5: 933,
#                       4: 189,
#                       8: 186,
#                       3: 56,
#                       2: 93,
#                       6: 76,
#                       0: 35,
#                       7: 19,
#                       1: 9,
#                       9: 16}),
#              (3, 4): Counter({3: 414, 8: 21, 9: 2}),
#              (2,
#               0): Counter({6: 1641,
#                       5: 35,
#                       0: 124,
#                       4: 42,
#                       3: 12,
#                       2: 46,
#                       8: 20,
#                       9: 3}),
#              (4, 3): Counter({1: 239, 3: 1, 2: 5, 4: 1, 7: 2, 8: 2}),
#              (0, 5): Counter({7: 721, 9: 8, 1: 1, 2: 6, 3: 1, 4: 1}),
#              (3,
#               9): Counter({2: 480,
#                       4: 72,
#                       7: 10,
#                       9: 14,
#                       6: 36,
#                       3: 4,
#                       8: 10,
#                       0: 2,
#                       5: 1}),
#              (7,
#               1): Counter({6: 114,
#                       3: 392,
#                       9: 339,
#                       5: 528,
#                       2: 245,
#                       1: 27,
#                       7: 114,
#                       8: 260,
#                       0: 34,
#                       4: 155}),
#              (10,
#               0): Counter({4: 565,
#                       2: 35,
#                       9: 176,
#                       5: 10,
#                       8: 11,
#                       7: 4,
#                       3: 2,
#                       6: 1}),
#              (1,
#               6): Counter({1: 34,
#                       2: 395,
#                       3: 53,
#                       0: 2,
#                       7: 1,
#                       4: 2,
#                       8: 1,
#                       5: 11}),
#              (8, 6): Counter({2: 326, 8: 68, 3: 19, 5: 1, 6: 2}),
#              (6,
#               0): Counter({4: 256,
#                       7: 258,
#                       9: 360,
#                       8: 27,
#                       3: 10,
#                       5: 15,
#                       1: 9,
#                       2: 1,
#                       6: 3}),
#              (8, 0): Counter({2: 51, 3: 6, 7: 98, 8: 2, 9: 2}),
#              (8, 8): Counter({6: 463, 0: 7, 5: 1, 8: 1}),
#              (5, 3): Counter({0: 144, 5: 33, 8: 15, 6: 95, 2: 3, 1: 1, 4: 3}),
#              (2, 3): Counter({5: 260, 3: 10, 6: 9, 2: 12, 0: 48, 4: 1}),
#              (3,
#               8): Counter({6: 1304,
#                       8: 16,
#                       0: 18,
#                       3: 7,
#                       5: 21,
#                       4: 20,
#                       2: 28,
#                       9: 1}),
#              (5,
#               7): Counter({7: 1192,
#                       9: 266,
#                       3: 19,
#                       4: 37,
#                       2: 31,
#                       5: 27,
#                       0: 5,
#                       8: 3}),
#              (6,
#               7): Counter({1: 1109,
#                       4: 20,
#                       2: 29,
#                       7: 62,
#                       6: 2,
#                       8: 16,
#                       3: 6,
#                       5: 1,
#                       9: 2}),
#              (1, 1): Counter({8: 965, 9: 6, 2: 21, 5: 53, 3: 3, 4: 7}),
#              (7, 5): Counter({3: 283, 8: 70, 9: 8, 2: 8, 7: 2, 5: 2}),
#              (0, 4): Counter({8: 235, 5: 19, 7: 5, 2: 11, 3: 11, 9: 5}),
#              (0,
#               2): Counter({9: 75,
#                       3: 1621,
#                       8: 692,
#                       5: 746,
#                       0: 88,
#                       2: 58,
#                       6: 14,
#                       1: 2,
#                       7: 5}),
#              (6, 9): Counter({0: 357, 5: 13, 9: 2, 8: 5, 3: 5, 2: 1}),
#              (5, 1): Counter({7: 495, 3: 1, 9: 4}),
#              (4, 8): Counter({9: 177, 7: 61, 4: 41, 8: 5}),
#              (6,
#               5): Counter({0: 1226,
#                       6: 13,
#                       8: 18,
#                       9: 10,
#                       5: 26,
#                       7: 5,
#                       2: 3,
#                       3: 1}),
#              (10,
#               7): Counter({4: 219,
#                       9: 93,
#                       8: 6,
#                       2: 6,
#                       6: 18,
#                       5: 2,
#                       0: 11,
#                       7: 2}),
#              (7,
#               3): Counter({4: 531,
#                       2: 75,
#                       7: 31,
#                       5: 42,
#                       9: 124,
#                       0: 15,
#                       6: 14,
#                       8: 14,
#                       3: 2}),
#              (9,
#               2): Counter({1: 1227,
#                       8: 70,
#                       2: 79,
#                       7: 109,
#                       4: 29,
#                       3: 13,
#                       9: 13,
#                       6: 6,
#                       5: 2,
#                       0: 1}),
#              (0,
#               9): Counter({0: 213,
#                       7: 39,
#                       6: 74,
#                       2: 78,
#                       5: 85,
#                       3: 25,
#                       9: 19,
#                       1: 26,
#                       4: 15,
#                       8: 27}),
#              (0, 8): Counter({0: 114, 5: 127, 8: 124, 9: 5, 3: 31, 6: 7}),
#              (9,
#               6): Counter({1: 175,
#                       2: 47,
#                       8: 25,
#                       3: 3,
#                       5: 5,
#                       6: 5,
#                       4: 2,
#                       7: 2}),
#              (5, 5): Counter({1: 415, 6: 10, 2: 29, 8: 9, 3: 1, 7: 6}),
#              (1, 10): Counter({2: 245, 8: 216, 5: 17, 3: 224, 1: 6, 0: 3}),
#              (6, 4): Counter({2: 498, 3: 4, 0: 3, 9: 1, 8: 1}),
#              (10, 5): Counter({7: 288, 0: 16, 9: 11, 3: 1, 2: 3}),
#              (10, 2): Counter({7: 546, 8: 2, 4: 2, 2: 3, 9: 2, 1: 2}),
#              (6, 3): Counter({1: 254, 6: 30, 8: 15, 5: 3, 3: 1, 0: 1, 2: 2}),
#              (2, 1): Counter({6: 24, 5: 143, 2: 6, 8: 15, 3: 2, 4: 4, 9: 7}),
#              (10, 9): Counter({0: 129, 3: 1, 2: 1}),
#              (8, 4): Counter({9: 353, 4: 63, 3: 3, 7: 10, 5: 1, 8: 4}),
#              (3, 5): Counter({0: 216, 6: 5, 5: 2, 2: 25, 8: 1}),
#              (2, 4): Counter({2: 100, 7: 6, 3: 10, 8: 33, 0: 2}),
#              (1, 3): Counter({0: 383, 6: 12, 8: 1, 2: 1, 9: 2}),
#              (7, 6): Counter({5: 2, 1: 272, 7: 8, 8: 2, 2: 3, 3: 3, 4: 3}),
#              (8, 5): Counter({5: 161, 8: 9, 6: 3, 3: 9, 0: 3}),
#              (8, 7): Counter({7: 392, 2: 71, 3: 6, 9: 12, 8: 9}),
#              (8,
#               10): Counter({1: 456,
#                       2: 41,
#                       5: 4,
#                       6: 6,
#                       3: 4,
#                       8: 6,
#                       7: 2,
#                       4: 1}),
#              (7, 8): Counter({7: 121, 9: 8, 0: 3, 4: 1, 6: 1, 5: 2}),
#              (7, 9): Counter({8: 19, 3: 1}),
#              (5, 9): Counter({8: 44, 2: 1}),
#              (2, 7): Counter({9: 32, 7: 4, 4: 6, 8: 1}),
#              (7,
#               4): Counter({3: 62,
#                       2: 34,
#                       7: 39,
#                       8: 31,
#                       9: 9,
#                       5: 3,
#                       1: 8,
#                       0: 1}),
#              (5, 10): Counter({3: 52, 5: 12, 8: 6}),
#              (9, 5): Counter({4: 223, 7: 1, 9: 19, 8: 1}),
#              (8, 1): Counter({6: 154, 4: 6, 2: 2}),
#              (0, 1): Counter({5: 128, 8: 8, 3: 2}),
#              (2, 5): Counter({3: 32, 5: 9, 8: 9}),
#              (0, 6): Counter({3: 1, 9: 24, 4: 11, 7: 7, 8: 2, 5: 1}),
#              (2,
#               9): Counter({5: 23, 9: 34, 3: 4, 4: 1, 6: 6, 8: 2, 2: 4, 0: 1}),
#              (10, 6): Counter({4: 2, 2: 23, 0: 21, 6: 3, 8: 1}),
#              (4, 6): Counter({2: 15, 8: 2, 7: 2}),
#              (4, 7): Counter({2: 3, 4: 2, 5: 16, 6: 22, 0: 4, 3: 3}),
#              (2, 8): Counter({4: 53}),
#              (8, 9): Counter({4: 54, 6: 7, 0: 2, 2: 2}),
#              (6, 1): Counter({7: 14, 2: 76, 4: 6, 8: 1}),
#              (4, 10): Counter({3: 90, 0: 1, 5: 5, 8: 4, 9: 2}),
#              (5, 8): Counter({8: 48, 5: 22, 3: 3, 9: 1}),
#              (9, 9): Counter({2: 26, 9: 2, 8: 8, 0: 6, 3: 2, 6: 1}),
#              (5, 6): Counter({6: 99, 0: 1}),
#              (10, 3): Counter({4: 6, 2: 4, 5: 7, 6: 1, 7: 1, 3: 3, 8: 1}),
#              (9, 7): Counter({3: 30, 8: 25, 5: 10}),
#              (4, 4): Counter({1: 2}),
#              (3, 7): Counter({2: 2, 3: 11, 5: 7})})

# %%
list(winmap.values())
# Out:
# [Counter({5: 663, 3: 1551, 8: 470, 9: 38, 2: 81, 0: 9, 6: 1, 1: 2, 7: 1}),
#  Counter({0: 2031, 5: 80, 2: 47, 9: 11, 3: 56, 6: 63, 8: 11, 7: 1, 4: 1}),
#  Counter({4: 1186, 9: 847, 8: 74, 0: 16, 2: 113, 6: 66, 5: 93, 7: 86, 3: 37}),
#  Counter({1: 1095, 7: 17, 2: 65, 4: 14, 8: 14, 3: 1, 6: 3, 9: 1}),
#  Counter({9: 1366, 4: 649, 1: 1, 8: 64, 2: 4, 7: 133, 5: 234, 3: 12}),
#  Counter({2: 455,
#           8: 1205,
#           3: 108,
#           5: 21,
#           6: 5,
#           4: 7,
#           9: 10,
#           1: 5,
#           7: 17,
#           0: 3}),
#  Counter({1: 944, 7: 32, 8: 25, 2: 2, 4: 29, 3: 25, 5: 12, 9: 12}),
#  Counter({4: 599,
#           9: 555,
#           7: 553,
#           3: 13,
#           8: 89,
#           1: 4,
#           2: 42,
#           5: 26,
#           5: 85,
#           3: 25,
#           9: 19,
#           1: 26,
#           4: 15,
#           8: 27}),
#  Counter({0: 114, 5: 127, 8: 124, 9: 5, 3: 31, 6: 7}),
#  Counter({1: 175, 2: 47, 8: 25, 3: 3, 5: 5, 6: 5, 4: 2, 7: 2}),
#  Counter({1: 415, 6: 10, 2: 29, 8: 9, 3: 1, 7: 6}),
#  Counter({2: 245, 8: 216, 5: 17, 3: 224, 1: 6, 0: 3}),
#  Counter({2: 498, 3: 4, 0: 3, 9: 1, 8: 1}),
#  Counter({7: 288, 0: 16, 9: 11, 3: 1, 2: 3}),
#  Counter({7: 546, 8: 2, 4: 2, 2: 3, 9: 2, 1: 2}),
#  Counter({1: 254, 6: 30, 8: 15, 5: 3, 3: 1, 0: 1, 2: 2}),
#  Counter({6: 24, 5: 143, 2: 6, 8: 15, 3: 2, 4: 4, 9: 7}),
#  Counter({0: 129, 3: 1, 2: 1}),
#  Counter({9: 353, 4: 63, 3: 3, 7: 10, 5: 1, 8: 4}),
#  Counter({0: 216, 6: 5, 5: 2, 2: 25, 8: 1}),
#  Counter({2: 100, 7: 6, 3: 10, 8: 33, 0: 2}),
#  Counter({0: 383, 6: 12, 8: 1, 2: 1, 9: 2}),
#  Counter({5: 2, 1: 272, 7: 8, 8: 2, 2: 3, 3: 3, 4: 3}),
#  Counter({5: 161, 8: 9, 6: 3, 3: 9, 0: 3}),
#  Counter({7: 392, 2: 71, 3: 6, 9: 12, 8: 9}),
#  Counter({1: 456, 2: 41, 5: 4, 6: 6, 3: 4, 8: 6, 7: 2, 4: 1}),
#  Counter({9: 168, 3: 5, 4: 43, 8: 63, 7: 7, 2: 1}),
#  Counter({7: 105, 8: 3, 2: 14, 9: 9}),
#  Counter({9: 206, 7: 40, 4: 22, 5: 6, 3: 5, 0: 2, 8: 9}),
#  Counter({6: 263, 8: 1, 0: 1, 5: 4, 3: 1}),
#  Counter({2: 98, 8: 1, 4: 1, 6: 1}),
#  Counter({7: 479, 9: 12, 5: 1}),
#  Counter({2: 127}),
#  Counter({2: 199, 3: 3}),
#  Counter({7: 82}),
#  Counter({2: 467, 8: 11, 7: 1}),
#  Counter({4: 282, 7: 2, 6: 1, 9: 1, 5: 1}),
#  Counter({6: 222, 9: 2, 0: 12, 5: 1}),
#  Counter({3: 310, 5: 5, 9: 2, 8: 4, 2: 4}),
#  Counter({5: 34, 3: 127, 8: 25, 9: 4, 2: 1}),
#  Counter({2: 321, 8: 2, 3: 4}),
#  Counter({6: 78, 1: 96, 2: 7, 8: 16, 7: 1, 4: 2, 5: 6}),
#  Counter({4: 179, 9: 32, 0: 2, 2: 3, 5: 2, 6: 2, 7: 1}),
#  Counter({9: 253, 4: 42, 7: 3, 2: 6, 8: 10, 5: 5, 3: 4}),
#  Counter({4: 9, 9: 89, 5: 3, 8: 2, 7: 12, 2: 1}),
#  Counter({0: 319, 6: 3, 8: 3, 4: 1}),
#  Counter({5: 174, 8: 56, 3: 44, 9: 3, 6: 1, 0: 1}),
#  Counter({0: 14, 6: 75, 2: 1}),
#  Counter({6: 296, 4: 2, 0: 2}),
#  Counter({8: 171, 9: 5, 5: 12, 1: 2, 7: 2, 2: 2, 0: 3, 4: 1}),
#  Counter({6: 210, 2: 2, 9: 1, 1: 1, 0: 3, 5: 1}),
#  Counter({5: 142, 8: 15, 3: 12, 9: 1, 1: 1}),
#  Counter({9: 68, 6: 2, 5: 2, 4: 17, 8: 8, 7: 1}),
#  Counter({1: 206, 6: 16, 5: 4, 2: 3, 8: 11, 4: 1}),
#  Counter({2: 296, 7: 1, 3: 1}),
#  Counter({2: 86, 0: 95, 8: 4, 6: 1, 7: 1}),
#  Counter({4: 98, 9: 3, 2: 3, 7: 1}),
#  Counter({2: 92, 4: 1}),
#  Counter({3: 176, 0: 2, 8: 10, 2: 9, 5: 3}),
#  Counter({0: 132, 2: 1}),
#  Counter({6: 138, 8: 8, 0: 16, 9: 1, 5: 4}),
#  Counter({1: 111, 8: 4, 4: 3, 2: 4, 6: 1, 7: 1}),
#  Counter({5: 247, 0: 8, 8: 3, 3: 12}),
#  Counter({5: 46, 3: 40, 7: 1, 8: 4, 0: 5, 6: 1}),
#  Counter({6: 186, 5: 12, 8: 4, 0: 1, 3: 8, 2: 8, 4: 1}),
#  Counter({7: 121, 9: 8, 0: 3, 4: 1, 6: 1, 5: 2}),
#  Counter({8: 19, 3: 1}),
#  Counter({8: 44, 2: 1}),
#  Counter({9: 32, 7: 4, 4: 6, 8: 1}),
#  Counter({3: 62, 2: 34, 7: 39, 8: 31, 9: 9, 5: 3, 1: 8, 0: 1}),
#  Counter({3: 52, 5: 12, 8: 6}),
#  Counter({4: 223, 7: 1, 9: 19, 8: 1}),
#  Counter({6: 154, 4: 6, 2: 2}),
#  Counter({5: 128, 8: 8, 3: 2}),
#  Counter({3: 32, 5: 9, 8: 9}),
#  Counter({3: 1, 9: 24, 4: 11, 7: 7, 8: 2, 5: 1}),
#  Counter({5: 23, 9: 34, 3: 4, 4: 1, 6: 6, 8: 2, 2: 4, 0: 1}),
#  Counter({4: 2, 2: 23, 0: 21, 6: 3, 8: 1}),
#  Counter({2: 15, 8: 2, 7: 2}),
#  Counter({2: 3, 4: 2, 5: 16, 6: 22, 0: 4, 3: 3}),
#  Counter({4: 53}),
#  Counter({4: 54, 6: 7, 0: 2, 2: 2}),
#  Counter({7: 14, 2: 76, 4: 6, 8: 1}),
#  Counter({3: 90, 0: 1, 5: 5, 8: 4, 9: 2}),
#  Counter({8: 48, 5: 22, 3: 3, 9: 1}),
#  Counter({2: 26, 9: 2, 8: 8, 0: 6, 3: 2, 6: 1}),
#  Counter({6: 99, 0: 1}),
#  Counter({4: 6, 2: 4, 5: 7, 6: 1, 7: 1, 3: 3, 8: 1}),
#  Counter({3: 30, 8: 25, 5: 10}),
#  Counter({1: 2}),
#  Counter({2: 2, 3: 11, 5: 7})]

# %%
np.sum(list(winmap.values()))
# Out:
# Counter({5: 5421,
#          3: 6131,
#          8: 5851,
#          9: 5949,
#          2: 5958,
#          0: 5923,
#          6: 5918,
#          1: 6742,
#          7: 6265,
#          4: 5842})
